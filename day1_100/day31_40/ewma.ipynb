# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('DailyDelhiClimateTest.csv')

# %%
df.head()
# Out:
#          date   meantemp   humidity  wind_speed  meanpressure
# 0  2017-01-01  15.913043  85.869565    2.743478     59.000000
# 1  2017-01-02  18.500000  77.222222    2.894444   1018.277778
# 2  2017-01-03  17.111111  81.888889    4.016667   1018.333333
# 3  2017-01-04  18.700000  70.050000    4.545000   1015.700000
# 4  2017-01-05  18.388889  74.944444    3.300000   1014.333333

# %%
d=df[['date','meantemp']]

# %%
d
# Out:
#            date   meantemp
# 0    2017-01-01  15.913043
# 1    2017-01-02  18.500000
# 2    2017-01-03  17.111111
# 3    2017-01-04  18.700000
# 4    2017-01-05  18.388889
# ..          ...        ...
# 109  2017-04-20  34.500000
# 110  2017-04-21  34.250000
# 111  2017-04-22  32.900000
# 112  2017-04-23  32.875000
# 113  2017-04-24  32.000000
#
# [114 rows x 2 columns]

# %%
plt.scatter(d['date'],d['meantemp'],color='red')

# %%
plt.scatter(df['date'],df['humidity'],color='red')

# %%
plt.scatter(df['date'],df['wind_speed'],color='red')

# %%
plt.scatter(df['date'],df['meanpressure'],color='red')

# %%
x1=d['meantemp'].ewm(alpha=0.7).mean(); x1
# Out:
# 0      15.913043
# 1      17.903010
# 2      17.333299
# 3      18.297802
# 4      18.361718
#          ...
# 109    34.193194
# 110    34.232958
# 111    33.299887
# 112    33.002466
# 113    32.300740
# Name: meantemp, Length: 114, dtype: float64

# %%
df=df[['date','meantemp']]

# %%
df['ewma']=x1

# %%
df
# Out:
#            date   meantemp       ewma
# 0    2017-01-01  15.913043  15.913043
# 1    2017-01-02  18.500000  17.903010
# 2    2017-01-03  17.111111  17.333299
# 3    2017-01-04  18.700000  18.297802
# 4    2017-01-05  18.388889  18.361718
# ..          ...        ...        ...
# 109  2017-04-20  34.500000  34.193194
# 110  2017-04-21  34.250000  34.232958
# 111  2017-04-22  32.900000  33.299887
# 112  2017-04-23  32.875000  33.002466
# 113  2017-04-24  32.000000  32.300740
#
# [114 rows x 3 columns]

# %%
plt.scatter(df['date'],df['meantemp'],color='red')
plt.plot(df['date'],x1,color='black',label='alpha=0.9')
plt.legend()
plt.show()

# %%
# 3 diff alpha values

# %%
plt.scatter(df['date'],df['meantemp'],color='red')
plt.plot(df['date'],x1,color='black',label='alpha=0.2')
plt.legend()
plt.show()

# %%
plt.scatter(df['date'],df['meantemp'],color='red')
plt.plot(df['date'],x1,color='black',label='alpha=0.5')
plt.legend()
plt.show()

# %%
plt.scatter(df['date'],df['meantemp'],color='red')
plt.plot(df['date'],x1,color='black',label='alpha=0.7')
plt.legend()
plt.show()
