# %%
import glob
from skimage import io
import skimage
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import os
dataset_path='E:\\Github\\deep_learning\\Projects\\blind_guidance\\data\\images'

# %%
    image=io.imread(dataset_path+'\\1.png')

# %%
i,(im1)=plt.subplots(1)
i.set_figwidth(15)
im1.imshow(image)
